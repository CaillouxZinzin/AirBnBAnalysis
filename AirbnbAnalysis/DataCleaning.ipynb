# %% [markdown]
# # Cleaning Airbnb Dataset

# %%
import sys
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ## Loading Files
#
#  - Set up the environment variable
#  - Load csv of each city

# %%
DIR_PATH =  os.getcwd()
DATA_PATH = os.path.join(DIR_PATH + os.sep, "data")
FRANCE_PATH = os.path.join(DATA_PATH + os.sep, "France")
LYON_PATH = os.path.join(FRANCE_PATH + os.sep, "Lyon" + os.sep)
PARIS_PATH = os.path.join(FRANCE_PATH + os.sep, "Paris" + os.sep)
BDX_PATH = os.path.join(FRANCE_PATH + os.sep, "Bordeaux" + os.sep)

# %%
paris_listings = pd.read_csv(PARIS_PATH+"listings.csv", low_memory=False)

# %%
paris_reviews = pd.read_csv(PARIS_PATH+"reviews.csv", low_memory=False)

# %%
paris_calendar = pd.read_csv(PARIS_PATH+"calendar.csv", low_memory=False)

# %% [markdown]
# ## Cleangin NaN datas and useless ones

# %%
paris_listings.head(5)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2577  https://www.airbnb.com/rooms/2577  20181207151406   2018-12-08
# 1  3109  https://www.airbnb.com/rooms/3109  20181207151406   2018-12-08
# 2  5396  https://www.airbnb.com/rooms/5396  20181207151406   2018-12-08
# 3  7397  https://www.airbnb.com/rooms/7397  20181207151406   2018-12-08
# 4  7964  https://www.airbnb.com/rooms/7964  20181207151406   2018-12-08
#
#                                 name  \
# 0   Loft for 4 by Canal Saint Martin
# 1                       zen and calm
# 2     Explore the heart of old Paris
# 3   MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 4  Large & sunny flat with balcony !
#
#                                              summary  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...
# 1  Appartement très calme de 50M2 Belle lumière D...
# 2  Cozy, well-appointed and graciously designed s...
# 3          VERY CONVENIENT, WITH THE BEST LOCATION !
# 4  Very large & nice apartment all for you!  - Su...
#
#                                                space  \
# 0  The district has any service or shop you may d...
# 1                   I bedroom appartment in Paris 14
# 2  Small, well appointed studio apartment at the ...
# 3  PLEASE ASK ME BEFORE TO MAKE A REQUEST !!! No ...
# 4  hello ! We have a great 75 square meter apartm...
#
#                                          description experiences_offered  \
# 0  100 m2 loft (1100 sq feet) with high ceiling, ...                none
# 1                   I bedroom appartment in Paris 14                none
# 2  Cozy, well-appointed and graciously designed s...                none
# 3  VERY CONVENIENT, WITH THE BEST LOCATION ! PLEA...                none
# 4  Very large & nice apartment all for you!  - Su...                none
#
#                                neighborhood_overview        ...          \
# 0                                                NaN        ...
# 1                                                NaN        ...
# 2  You are within walking distance to the Louvre,...        ...
# 3                                                NaN        ...
# 4                                                NaN        ...
#
#   requires_license        license jurisdiction_names instant_bookable  \
# 0                t            NaN            {PARIS}                t
# 1                t            NaN            {PARIS}                f
# 2                t            NaN            {PARIS}                t
# 3                t  7510400829623            {PARIS}                f
# 4                t            NaN            {PARIS}                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f                     flexible
# 2                        f  strict_14_with_grace_period
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#    require_guest_profile_picture require_guest_phone_verification  \
# 0                              f                                f
# 1                              f                                f
# 2                              f                                f
# 3                              f                                f
# 4                              f                                f
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1                NaN
# 1                               1               0.29
# 2                               1               1.29
# 3                               1               2.47
# 4                               1               0.06
#
# [5 rows x 96 columns]

# %%
"""
paris_listings = paris_listings.drop(['listing_url', 'scrape_id', 'last_scraped', 'experiences_offered', 'neighborhood_overview'], axis=1)
paris_listings = paris_listings.drop(['is_business_travel_ready', 'license', 'description', 'require_guest_profile_picture', 'require_guest_phone_verification'], axis=1)
paris_listings = paris_listings.drop(['calculated_host_listings_count', 'requires_license', 'notes'], axis=1)
paris_listings = paris_listings.drop(['transit', 'space', 'summary', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url'], axis=1)
paris_listings = paris_listings.drop(['host_name', 'host_url', 'xl_picture_url', 'picture_url', 'access', 'host_location', 'cancellation_policy'], axis=1)
paris_listings = paris_listings.drop(['host_about', 'host_response_time', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url'], axis=1)
"""
paris_listings = paris_listings.loc[:,['id', 'host_id', 'host_since', 'host_response_rate', 'reviews_per_month', 'review_scores_value', 'review_scores_location', 'review_scores_communication', 
'review_scores_checkin', 'review_scores_cleanliness', 'review_scores_rating', 'price', 'cleaning_fee', 'zipcode', 'number_of_reviews']]

# %%
paris_listings = paris_listings.dropna(how='any')
paris_listings
# Out:
#              id    host_id  host_since host_response_rate  reviews_per_month  \
# 1          3109       3631  2008-10-14               100%               0.29
# 2          5396       7903  2009-02-14               100%               1.29
# 3          7397       2626  2008-08-30               100%               2.47
# 4          7964      22155  2009-06-18                75%               0.06
# 7          9952      33534  2009-08-24                80%               0.24
# 8         10010      33995  2009-08-26               100%               1.33
# 9         10270      33995  2009-08-26               100%               1.46
# 10        10586      37107  2009-09-08                86%               0.38
# 12        10710      38170  2009-09-13                80%               0.36
# 15        11265      41718  2009-09-28               100%               0.43
# 16        11487      42666  2009-10-01               100%               0.03
# 18        11848      44626  2009-10-09               100%               2.98
# 21        14011      55023  2009-11-17               100%               0.16
# 23        14757      57954  2009-11-27               100%               2.02
# 24        16455      64054  2009-12-18               100%               0.30
# 25        16457      64057  2009-12-18               100%               3.11
# 26        16469      64075  2009-12-18               100%               1.09
# 28        17283      67010  2010-01-01               100%               0.64
# 35        19306      73530  2010-01-25               100%               1.74
# 36        20823      73530  2010-01-25               100%               1.59
# 37        21004      79843  2010-02-10                80%               0.88
# 38        21167      80630  2010-02-12               100%               0.67
# 39        21194      73530  2010-01-25               100%               1.41
# 40        21264      81070  2010-02-14               100%               0.19
# 47        22979      89023  2010-03-06               100%               2.21
# 48        23441      91706  2010-03-12                80%               0.66
# 50        23742      94254  2010-03-16               100%               0.23
# 56        26567     112799  2010-04-23               100%               0.10
# 57        26827     114407  2010-04-27               100%               0.70
# 58        26939     115043  2010-04-28               100%               0.31
# ...         ...        ...         ...                ...                ...
# 58757  30219699   54853822  2016-01-16               100%               1.00
# 58763  30221393   61980761  2016-03-07               100%               1.00
# 58769  30223561  226981741  2018-11-22               100%               2.00
# 58775  30224716   17037121  2014-06-20                81%               1.00
# 58785  30227064    7621082  2013-07-21               100%               3.00
# 58786  30227794  215342844  2018-09-14               100%               3.00
# 58789  30229384   83465357  2016-07-13               100%               2.00
# 58792  30230429    7017259  2013-06-20                88%               3.00
# 58810  30242301   37881126  2015-07-08               100%               1.00
# 58816  30243418  227117086  2018-11-23               100%               4.00
# 58852  30251738   48556297  2015-11-09               100%               1.00
# 58858  30253192  227188484  2018-11-23                94%               5.00
# 58862  30256336  202672896  2018-07-16               100%               1.00
# 58869  30260256   41852092  2015-08-18               100%               1.00
# 58884  30263517   86734217  2016-07-29               100%               1.00
# 58900  30266501  227313245  2018-11-24               100%               1.00
# 58917  30278899   39171862  2015-07-21                80%               3.00
# 58920  30279752   11588997  2014-01-24                50%               1.00
# 58928  30281035    3277663  2012-08-16               100%               1.00
# 58943  30285081     335526  2011-01-05               100%               2.00
# 58944  30285263  227459391  2018-11-25               100%               1.00
# 58994  30305581    9538129  2013-10-20               100%               1.00
# 59068  30319744   31602150  2015-04-20                93%               2.00
# 59068                        8.0                  80.0   $50.00       $20.00
# 59071                       10.0                 100.0   $75.00       $25.00
# 59123                       10.0                 100.0  $119.00       $65.00
# 59152                        6.0                  80.0   $65.00       $15.00
# 59172                       10.0                 100.0   $52.00       $10.00
# 59184                        8.0                 100.0   $50.00       $60.00
# 59299                       10.0                 100.0  $160.00       $30.00
# 59369                        9.0                  80.0   $50.00       $10.00
#
#       zipcode  number_of_reviews
# 1       75014                  7
# 2       75004                148
# 3       75004                231
# 4       75009                  6
# 7       75011                 17
# 8       75011                144
# 9       75011                147
# 10      75018                 41
# 12      75008                 38
# 15      75018                 13
# 16      75011                  2
# 18      75011                293
# 21      75009                 17
# 23      75018                193
# 24      75013                 16
# 25      75004                331
# 26      75010                118
# 28      75010                 49
# 35      75005                186
# 36      75005                168
# 37      75012                 93
# 38      75018                 71
# 39      75005                147
# 40      75011                 19
# 47      75004                230
# 48      75018                 70
# 50      75020                  4
# 56      75017                  9
# 57      75020                 73
# 58      75005                 32
# ...       ...                ...
# 58757   75009                  1
# 58763   75116                  1
# 58769   75001                  2
# 58775   75011                  1
# 58785   75009                  3
# 58786   75013                  3
# 58789   75012                  2
# 58792   75018                  3
# 58810   75020                  1
# 58816   75006                  4
# 58852   75010                  1
# 58858   92130                  5
# 58862   75003                  1
# 58869   75002                  1
# 58884   69100                  1
# 58900   75009                  1
# 58917   75019                  3
# 58920   75013                  1
# 58928   75011                  1
# 58943   75002                  2
# 58944   75002                  1
# 58994   75010                  1
# 59068   75019                  2
# 59071   75017                  1
# 59123   75017                  1
# 59152   75005                  1
# 59172   75010                  1
# 59184   75014                  1
# 59299   75015                  3
# 59369   75015                  2
#
# [22104 rows x 15 columns]

# %%
# sort by price
paris_listings_per_price = paris_listings.sort_values(by="price")
paris_listings_per_price.head(5)
# Out:
#              id    host_id  host_since host_response_rate  reviews_per_month  \
# 41261  21422028   25838188  2015-01-09                89%               0.16
# 40035  20724108  117929471  2017-02-24               100%               0.40
# 38497  19974916   54081344  2016-01-10               100%               2.71
# 40851  21202285    5902799  2013-04-13               100%               1.76
# 39420  20291987   66618414  2016-04-10               100%               1.22
#
#        review_scores_value  review_scores_location  \
# 41261                  9.0                    10.0
# 40035                  9.0                    10.0
# 38497                  9.0                    10.0
# 40851                  9.0                    10.0
# 39420                  9.0                    10.0
#
#        review_scores_communication  review_scores_checkin  \
# 41261                          9.0                    9.0
# 40035                         10.0                   10.0
# 38497                         10.0                   10.0
# 40851                          9.0                    9.0
# 39420                         10.0                   10.0
#
#        review_scores_cleanliness  review_scores_rating  price cleaning_fee  \
# 41261                       10.0                 100.0    0.0       $90.00
# 40035                        7.0                  87.0    0.0       $40.00
# 38497                        9.0                  90.0    0.0       $40.00
# 40851                        8.0                  94.0    0.0       $45.00
# 39420                       10.0                  92.0    0.0       $50.00
#
#       zipcode  number_of_reviews
# 41261   75011                  2
# 40035   75016                  6
# 38497   75018                 41
# 40851   75005                 20
# 39420   75116                 18

# %%
paris_listings.price = [x.strip('$') for x in paris_listings.price]
paris_listings.price = paris_listings.price.apply(lambda x: x.replace(',',''))

# %%
#mean of price in paris
paris_listings["price"] = pd.to_numeric(paris_listings["price"])
mean_price_paris = paris_listings.price.mean()
mean_price_paris
# Out:
# 113.4619073470865
